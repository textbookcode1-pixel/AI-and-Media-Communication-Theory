# %% [markdown]
# # 교재_인공지능과 미디어커뮤니케이션이론_코드
#
# # 목록
#
# 제1장 인공지능 시대의 미디어 커뮤니케이션 패러다임
#
# 제2장 미디어 산업의 AI 적용 사례와 이론적 쟁점
#
# 제3장 지도학습 I — 분류와 회귀의 커뮤니케이션 연구 적용
#
# 제4장 지도학습 II — 의사결정나무·SVM·앙상블
#
# 제5장 모델 평가와 해석가능성
#
# 제6장 신경망의 원리와 합성곱 신경망(CNN)
#
# 제7장 순환 신경망(RNN)과 LSTM — 시계열·텍스트 분석
#
# 제8장 생성 모델 — GAN과 Diffusion의 미디어 함의
#
# 제9장 대규모 언어 모델(LLM)과 프롬프트 엔지니어링
#
# 제10장 NLP 응용과 미디어 연구 — 텍스트 분석의 다층적 통합
#
# 제11장 학술 출판에서의 AI 방법론 — 보고·저자성·윤리
#
# 제12장 학위논문과 개방형 학술 연구 — 분석 마무리
