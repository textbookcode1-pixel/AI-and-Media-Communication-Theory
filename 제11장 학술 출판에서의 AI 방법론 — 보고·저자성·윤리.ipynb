# %% [markdown]
# 코드 llm-metadata

# %%
{
  "llm_metadata": {
    "model": "claude-opus-4-7",
    "provider": "Anthropic",
    "api_version": "2026-04-16",
    "call_date_range": "2026-05-01 ~ 2026-05-15",
    "system_prompt_file": "appendix_A_system_prompt.md",
    "user_message_template": "기사: {article_text}",
    "parameters": {
      "temperature": 0,
      "max_tokens": 1500,
      "top_p": 1.0,
      "response_format": "json_object"
    },
    "validation": {
      "sample_size": 200,
      "human_coders": 2,
      "krippendorff_alpha_human": 0.78,
      "krippendorff_alpha_llm_vs_human": 0.74,
      "krippendorff_alpha_llm_consistency": 0.94
    },
    "cost_estimate_usd": 87.50,
    "total_calls": 8800,
    "failed_calls": 12
  }
}
